# %% [markdown]
# ### MINI-SUPERMARKET WEEKLY ANALYSIS
#
# This notebook focuses on the weekly analysis of Fake Random Data generated by me for A small shop that sells confectionaries. Number of items sold daily for each product ranged from 15 to 49 for a period of seven days. `The total income for the shop  per day` will be calculated as well as the `total income for the week`. `Average nummber of each product sold per week` will be calculated as well.
#
#
# #### DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


# Setting random seed for consistency
np.random.seed(42)

product_names = ["Bread", "Milk", "Soda", "Canned Water", "Lolipop", "Peanut", "Groundnuts", "Wine"]
days_of_the_week = ["Sun", 'Mon', 'Tues', "Wed", 'Thurs', "Fri", "Sat"]
food_prices = pd.DataFrame(np.array([10, 25, 15, 10, 20, 10, 20, 40]).reshape(1,8), columns=product_names, index=["Prices"])
food_sold = pd.DataFrame(np.random.randint(15, 49, size=(7,8)), columns=product_names, index=[days_of_the_week])

print(food_prices)
print(food_sold)
# Out:
#         Bread  Milk  Soda  Canned Water  Lolipop  Peanut  Groundnuts  Wine
# Prices     10    25    15            10       20      10          20    40
#        Bread  Milk  Soda  Canned Water  Lolipop  Peanut  Groundnuts  Wine
# Sun       43    29    22            35       33      37          25    25
# Mon       38    38    17            36       16      38          44    16
# Tues      35    47    26            36       39      41          42    30
# Wed       29    17    21            35       23      32          18    39
# Thurs     28    23    40            16       34      42          21    22
# Fri       28    31    18            16       20      18          43    32
# Sat       40    48    24            28       45      29          22    28

# %% [markdown]
# ####  EXPLORATORY DATA ANALYSIS ON DAILY SALES

# %%
# Total amount sold in a day for all the food items
daily_sales = np.dot(food_sold, food_prices.T)
food_sold["Daily_sales($)"] = daily_sales

food_sold
# Out:
#        Bread  Milk  Soda  Canned Water  Lolipop  Peanut  Groundnuts  Wine  \
# Sun       43    29    22            35       33      37          25    25
# Mon       38    38    17            36       16      38          44    16
# Tues      35    47    26            36       39      41          42    30
# Wed       29    17    21            35       23      32          18    39
# Thurs     28    23    40            16       34      42          21    22
# Fri       28    31    18            16       20      18          43    32
# Sat       40    48    24            28       45      29          22    28
#
#        Daily_sales($)
# Sun              4365
# Mon              4165
# Tues             5505
# Wed              4080
# Thurs            4015
# Fri              4205
# Sat              4990

# %%
# Out:
#        Products  Average-in-the-week
# 0         Bread            34.428571
# 5        Peanut            33.857143
# 1          Milk            33.285714
# 6    Groundnuts            30.714286
# 4       Lolipop            30.000000
# 3  Canned Water            28.857143
# 7          Wine            27.428571
# 2          Soda            24.000000

# %%
# Avearge product sold per day
bread_sold_average = np.mean(food_sold["Bread"])
milk_sold_average =  np.mean(food_sold["Milk"])
soda_sold_average = np.mean(food_sold["Soda"])
canned_water_sold_average = np.mean(food_sold["Canned Water"])
lolipop_sold_average = np.mean(food_sold["Lolipop"])
peanuts_sold_average = np.mean(food_sold["Peanut"])
groundnut_sold_average = np.mean(food_sold["Groundnuts"])
wine_sold_average = np.mean(food_sold["Wine"])



average = [bread_sold_average, 
           milk_sold_average, 
           soda_sold_average, 
           canned_water_sold_average,
           lolipop_sold_average, 
           peanuts_sold_average, 
           groundnut_sold_average, 
           wine_sold_average]

average_df = pd.DataFrame({"Products": product_names, "Average-in-the-week":average})
sorted_df = average_df.sort_values("Average-in-the-week", ascending=False)


fig, ax = plt.subplots()
ax = ax.barh(sorted_df["Products"], sorted_df["Average-in-the-week"], color=["g"])
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Interpretation from the graph:
# * On average, Bread and peanut sold the highest daily, followed closely by Milk and Groundnuts. Funny enough soda sold the lowest that week below wine.
#
# ##### This can be viewed in a `Pie Chart` below
#
# Though the bar chart shows the most undertandable results, the pie chart below also confirmed the results from the bar chart as clearly we can see the percentage of every product. Bread and Peanut sold the highest followed closely by milk and groundnuts, however soda sold the loweset.

# %%
values = average
labels = product_names
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.title('Average product Sold in a day')
plt.show()

# %%
food_sold.hist(figsize=(10,10), bins=2);

# %% [markdown]
# interpretations from the histogram:
# 1. 30 pieces of bread and above per day was bought quite often during the week
# 2. 20 to 30 satchets of milk was bought quite often
# 3. 20 to 17 cans of soda was bought quite often.
# 4. 25 to 35 cans of water was bought quite often.
# 5. 30 to 40 sticks of lolipop was bought quite often in the shop.
# 6. 30 to 40 satchets of peanut was bought quite often
# 7. 20 to 30 packs of groundnuts was bought quite often.
# 8. 30 to 40 bottles of wine was bought quite often
# 9. Daily sales was between 4000 dollars a day to 4600 dollars a day
#
#
# ####  TOTAL SHOP INCOME FOR THE WEEK

# %%
total_sales = np.sum(food_sold["Daily_sales($)"])
print(f"Total Shop Income For The Week: ${total_sales}")
# Out:
# Total Shop Income For The Week: $31325

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax=sns.boxplot(data=food_sold.drop("Daily_sales($)", axis=1))
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# ### Interpreting The Boxplot
# 1. Median bread sales = 35
# 2. Median milk sales = 32
# 3. Median  soda sales = 23 outilier of (40)
# 4. Median canned water sales = 35
# 5. Median Lolipop sales = 33
# 6. Median Peanut sales = 37
# 7. Median groundnut sales = 25
# 8. Median Wine sales = 27

# %% [markdown]
# #### CHECKING FOR CORRELATIONS

# %%
correlation_matrix = food_sold.corr()
fig, ax = plt.subplots(figsize=(15,5))
sns.heatmap(correlation_matrix, annot=True, cbar=False);

# %% [markdown]
# #### Interpreting Correlation For  Bread
# ##### As Bread sales increased There exist a chance that:
# 1. Milk sales increased by 55 percent. (medium positive correlation)
# 2. Soda sales decreased by 31 percent (low negative correlation)
# 3. Canned water sales increased by 61 percent. (high positive correlation)
# 4. Lolipop sales increased by 36 percent. (low positive correlation
# 5. Peanut sales increased by 25 percent. (low positive correlation)
# 6. Groundnut sales increased by 2 percent. ( low positive correlation)
# 7. Wine sales decreased by 42 percent. ( medium Negative correlation)
# 8. Daily percent increased by 40 percent ( medium positive correlation)
#
#
# #### Interpreting Correlation For Daily Sales
# ##### As Daily Sales increased there exist a chance that:
# 1. Bread sales increased by 40 percent (medium positive correlation)
# 2. Milk sales increased by 83 percent (High positive correlation)
# 3. Soda sales decreased by 0.4 percent (High negative correlation)
# 4. Canned water sales increased by 36 percent (low positive correlation)
# 5. Lolipop sales increased by 69 percent (high positive correlation)
# 6. Peanut sales increased by 16 percent (low positive correlation)
# 7. Groundnut sales increased by 25 percent (low positive correlation)
# 8. Wine sales increased by 14 percent (low positive correlation)

# %% [markdown]
# ### Five point Summary for sales

# %%
food_sold.describe()
# Out:
#            Bread       Milk      Soda  Canned Water    Lolipop     Peanut  \
# count   7.000000   7.000000   7.00000      7.000000   7.000000   7.000000
# mean   34.428571  33.285714  24.00000     28.857143  30.000000  33.857143
# std     6.187545  11.700631   7.72442      9.209209  10.614456   8.395010
# min    28.000000  17.000000  17.00000     16.000000  16.000000  18.000000
# 25%    28.500000  26.000000  19.50000     22.000000  21.500000  30.500000
# 50%    35.000000  31.000000  22.00000     35.000000  33.000000  37.000000
# 75%    39.000000  42.500000  25.00000     35.500000  36.500000  39.500000
# max    43.000000  48.000000  40.00000     36.000000  45.000000  42.000000
#
#        Groundnuts       Wine  Daily_sales($)
# count    7.000000   7.000000        7.000000
# mean    30.714286  27.428571     4475.000000
# std     11.686378   7.390470      558.994633
# min     18.000000  16.000000     4015.000000
# 25%     21.500000  23.500000     4122.500000
# ...

# %% [markdown]
# #### Interpretation:
#
# 1. Count for each week was recorded.
# 2. Five point summary = min, 25%, 50%, 75%  and max
#
#
# ##### Describing Daily sales:
# 1. Income for each day was captured (count=7)
# 2. Average daily income = 4475 dollars
# 3. Standard Deviation = 558 dollars
# 4. Lowest income in a day = 4015 dollars
# 5. 25 percent of all income = 4122 dollars
# 6. Median income = 4205 dollars
# 7. 75 percent of all income =  4677.50 dollars
# 8. Highest income in a day = 5505 dollars
